# %% [markdown]
# ## **01 Data Visualization**
# ---
#
# Here we go through the processed data. This notebook assumes you have already run [`00_build_data.ipynb`](00_build_data.ipynb) to generate the processed data.
